# %% [markdown]
# # Flight Price Prediction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
train_df=pd.read_excel('C:/Users/Admin/Downloads/Data_Train.xlsx')
test_df=pd.read_excel('C:/Users/Admin/Downloads/Test_set.xlsx')

# %%
train_df.shape
# Out:
# (10683, 11)

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info
# 2667    14:20         16:55   2h 35m    non-stop         No info
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info
# 2669    04:00         19:15  15h 15m      1 stop         No info
# 2670    04:55         19:15  14h 20m      1 stop         No info

# %%
train_df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
train_df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
big_df=train_df.append(test_df,sort=False)

# %%
big_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
big_df.shape
# Out:
# (13354, 11)

# %%
big_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# dtype: object

# %% [markdown]
# # Feature Engineering

# %%
big_df['Date']=big_df['Date_of_Journey'].str.split('/').str[0]
big_df['Month']=big_df['Date_of_Journey'].str.split('/').str[1]
big_df['Year']=big_df['Date_of_Journey'].str.split('/').str[2]

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                object
# Month               object
# Year                object
# dtype: object

# %%
big_df.drop( columns=['Date_of_Journey'],inplace=True,axis=1)

# %%
big_df['Date']=big_df['Date'].astype(int)
big_df['Month']=big_df['Month'].astype(int)
big_df['Year']=big_df['Year'].astype(int)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0     9      6
# 3         23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4         21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
big_df['Arrival_Time']=big_df['Arrival_Time'].str.split(' ').str[0]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
big_df[big_df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Dep_Time Arrival_Time Duration  \
# 9039  Air India  Delhi      Cochin   NaN    09:45        09:25  23h 40m
#
#      Total_Stops Additional_Info   Price  Date  Month  Year
# 9039         NaN         No info  7480.0     6      5  2019

# %%
big_df['Total_Stops']=big_df['Total_Stops'].fillna('1 stop')

# %%
big_df[big_df['Total_Stops'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price, Date, Month, Year]
# Index: []

# %%
big_df['Total_Stops']=big_df['Total_Stops'].replace('non-stop','0 stop')

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m      0 stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
big_df['Stop']= big_df['Total_Stops'].str.split(' ').str[0]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m      0 stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year Stop
# 0  2019    0
# 1  2019    2
# 2  2019    2
# 3  2019    1
# 4  2019    1

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Stop                object
# dtype: object

# %%
big_df['Stop']=big_df['Stop'].astype(int)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m      0 stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year  Stop
# 0  2019     0
# 1  2019     2
# 2  2019     2
# 3  2019     1
# 4  2019     1

# %%
big_df.drop('Total_Stops',axis=1,inplace=True)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Additional_Info    Price  Date  Month  Year  Stop
# 0        01:10   2h 50m         No info   3897.0    24      3  2019     0
# 1        13:15   7h 25m         No info   7662.0     1      5  2019     2
# 2        04:25      19h         No info  13882.0     9      6  2019     2
# 3        23:30   5h 25m         No info   6218.0    12      5  2019     1
# 4        21:35   4h 45m         No info  13302.0     1      3  2019     1

# %%
big_df['Arrival_Hour']=big_df['Arrival_Time'].str.split(':').str[0]
big_df['Arrival_Minute']=big_df['Arrival_Time'].str.split(':').str[1]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Additional_Info    Price  Date  Month  Year  Stop  \
# 0        01:10   2h 50m         No info   3897.0    24      3  2019     0
# 1        13:15   7h 25m         No info   7662.0     1      5  2019     2
# 2        04:25      19h         No info  13882.0     9      6  2019     2
# 3        23:30   5h 25m         No info   6218.0    12      5  2019     1
# 4        21:35   4h 45m         No info  13302.0     1      3  2019     1
#
#   Arrival_Hour Arrival_Minute
# 0           01             10
# 1           13             15
# 2           04             25
# 3           23             30
# 4           21             35

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Additional_Info    Price  Date  Month  Year  Stop  \
# 0        01:10   2h 50m         No info   3897.0    24      3  2019     0
# 1        13:15   7h 25m         No info   7662.0     1      5  2019     2
# 2        04:25      19h         No info  13882.0     9      6  2019     2
# 3        23:30   5h 25m         No info   6218.0    12      5  2019     1
# 4        21:35   4h 45m         No info  13302.0     1      3  2019     1
#
#   Arrival_Hour Arrival_Minute
# 0           01             10
# 1           13             15
# 2           04             25
# 3           23             30
# 4           21             35

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Stop                 int32
# Arrival_Hour        object
# Arrival_Minute      object
# dtype: object

# %%
big_df['Arrival_Hour']=big_df['Arrival_Hour'].astype(int)
big_df['Arrival_Minute']=big_df['Arrival_Minute'].astype(int)

# %%
big_df.drop('Arrival_Time',inplace=True,axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019     0             1
# 1         No info   7662.0     1      5  2019     2            13
# 2         No info  13882.0     9      6  2019     2             4
# 3         No info   6218.0    12      5  2019     1            23
# 4         No info  13302.0     1      3  2019     1            21
#
#    Arrival_Minute
# 0              10
# 1              15
# 2              25
# 3              30
# 4              35

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Duration            object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Stop                 int32
# Arrival_Hour         int32
# Arrival_Minute       int32
# dtype: object

# %%
big_df['Departure_Hour']=big_df['Dep_Time'].str.split(':').str[0]
big_df['Departure_Minute']=big_df['Dep_Time'].str.split(':').str[1]

# %%
big_df['Departure_Hour']=big_df['Departure_Hour'].astype(int)
big_df['Departure_Minute']=big_df['Departure_Minute'].astype(int)
big_df.drop('Dep_Time',inplace=True,axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019     0             1
# 1         No info   7662.0     1      5  2019     2            13
# 2         No info  13882.0     9      6  2019     2             4
# 3         No info   6218.0    12      5  2019     1            23
# 4         No info  13302.0     1      3  2019     1            21
#
#    Arrival_Minute  Departure_Hour  Departure_Minute
# 0              10              22                20
# 1              15               5                50
# 2              25               9                25
# 3              30              18                 5
# 4              35              16                50

# %%
big_df.dtypes
# Out:
# Airline              object
# Source               object
# Destination          object
# Route                object
# Duration             object
# Additional_Info      object
# Price               float64
# Date                  int32
# Month                 int32
# Year                  int32
# Stop                  int32
# Arrival_Hour          int32
# Arrival_Minute        int32
# Departure_Hour        int32
# Departure_Minute      int32
# dtype: object

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019     0             1
# 1         No info   7662.0     1      5  2019     2            13
# 2         No info  13882.0     9      6  2019     2             4
# 3         No info   6218.0    12      5  2019     1            23
# 4         No info  13302.0     1      3  2019     1            21
#
#    Arrival_Minute  Departure_Hour  Departure_Minute
# 0              10              22                20
# 1              15               5                50
# 2              25               9                25
# 3              30              18                 5
# 4              35              16                50

# %%
big_df['Route_1']=big_df['Route'].str.split('→ ').str[0]
big_df['Route_2']=big_df['Route'].str.split('→ ').str[1]
big_df['Route_3']=big_df['Route'].str.split('→ ').str[2]
big_df['Route_4']=big_df['Route'].str.split('→ ').str[3]
big_df['Route_5']=big_df['Route'].str.split('→ ').str[4]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019     0             1
# 1         No info   7662.0     1      5  2019     2            13
# 2         No info  13882.0     9      6  2019     2             4
# 3         No info   6218.0    12      5  2019     1            23
# 4         No info  13302.0     1      3  2019     1            21
#
#    Arrival_Minute  Departure_Hour  Departure_Minute Route_1 Route_2 Route_3  \
# 0              10              22                20    BLR      DEL     NaN
# 1              15               5                50    CCU     IXR     BBI
# 2              25               9                25    DEL     LKO     BOM
# 3              30              18                 5    CCU     NAG      BLR
# 4              35              16                50    BLR     NAG      DEL
#
#   Route_4 Route_5
# 0     NaN     NaN
# 1     BLR     NaN
# 2     COK     NaN
# 3     NaN     NaN
# 4     NaN     NaN

# %%
big_df['Route_1']=big_df['Route_1'].fillna('None')
big_df['Route_2']=big_df['Route_2'].fillna('None')
big_df['Route_3']=big_df['Route_3'].fillna('None')
big_df['Route_4']=big_df['Route_4'].fillna('None')
big_df['Route_5']=big_df['Route_5'].fillna('None')

# %%
big_df['Price'].isnull().sum()
# Out:
# 2671

# %%
big_df['Price']=big_df['Price'].fillna(big_df['Price'].mean())

# %%
big_df['Price'].isnull().sum()
# Out:
# 0

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019     0             1
# 1         No info   7662.0     1      5  2019     2            13
# 2         No info  13882.0     9      6  2019     2             4
# 3         No info   6218.0    12      5  2019     1            23
# 4         No info  13302.0     1      3  2019     1            21
#
#    Arrival_Minute  Departure_Hour  Departure_Minute Route_1 Route_2 Route_3  \
# 0              10              22                20    BLR      DEL    None
# 1              15               5                50    CCU     IXR     BBI
# 2              25               9                25    DEL     LKO     BOM
# 3              30              18                 5    CCU     NAG      BLR
# 4              35              16                50    BLR     NAG      DEL
#
#   Route_4 Route_5
# 0    None    None
# 1     BLR    None
# 2     COK    None
# 3    None    None
# 4    None    None

# %%
big_df.drop(['Route','Duration'],axis=1,inplace=True)

# %%
big_df.head()
# Out:
#        Airline    Source Destination Additional_Info    Price  Date  Month  \
# 0       IndiGo  Banglore   New Delhi         No info   3897.0    24      3
# 1    Air India   Kolkata    Banglore         No info   7662.0     1      5
# 2  Jet Airways     Delhi      Cochin         No info  13882.0     9      6
# 3       IndiGo   Kolkata    Banglore         No info   6218.0    12      5
# 4       IndiGo  Banglore   New Delhi         No info  13302.0     1      3
#
#    Year  Stop  Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  \
# 0  2019     0             1              10              22                20
# 1  2019     2            13              15               5                50
# 2  2019     2             4              25               9                25
# 3  2019     1            23              30              18                 5
# 4  2019     1            21              35              16                50
#
#   Route_1 Route_2 Route_3 Route_4 Route_5
# 0    BLR      DEL    None    None    None
# 1    CCU     IXR     BBI      BLR    None
# 2    DEL     LKO     BOM      COK    None
# 3    CCU     NAG      BLR    None    None
# 4    BLR     NAG      DEL    None    None

# %%
big_df.isnull().sum()
# Out:
# Airline             0
# Source              0
# Destination         0
# Additional_Info     0
# Price               0
# Date                0
# Month               0
# Year                0
# Stop                0
# Arrival_Hour        0
# Arrival_Minute      0
# Departure_Hour      0
# Departure_Minute    0
# Route_1             0
# Route_2             0
# Route_3             0
# Route_4             0
# Route_5             0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
big_df['Airline']=encoder.fit_transform(big_df['Airline'])
big_df['Source']=encoder.fit_transform(big_df['Source'])
big_df['Destination']=encoder.fit_transform(big_df['Destination'])
big_df['Additional_Info']=encoder.fit_transform(big_df['Additional_Info'])
big_df['Route_1']=encoder.fit_transform(big_df['Route_1'])
big_df['Route_2']=encoder.fit_transform(big_df['Route_2'])
big_df['Route_3']=encoder.fit_transform(big_df['Route_3'])
big_df['Route_4']=encoder.fit_transform(big_df['Route_4'])
big_df['Route_5']=encoder.fit_transform(big_df['Route_5'])

# %%
big_df.head()
# Out:
#    Airline  Source  Destination  Additional_Info    Price  Date  Month  Year  \
# 0        3       0            5                8   3897.0    24      3  2019
# 1        1       3            0                8   7662.0     1      5  2019
# 2        4       2            1                8  13882.0     9      6  2019
# 3        3       3            0                8   6218.0    12      5  2019
# 4        3       0            5                8  13302.0     1      3  2019
#
#    Stop  Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  \
# 0     0             1              10              22                20
# 1     2            13              15               5                50
# 2     2             4              25               9                25
# 3     1            23              30              18                 5
# 4     1            21              35              16                50
#
#    Route_1  Route_2  Route_3  Route_4  Route_5
# 0        0       13       24       12        4
# 1        2       25        1        3        4
# 2        3       32        4        5        4
# 3        2       34        3       12        4
# 4        0       34        8       12        4

# %%
big_df.dtypes
# Out:
# Airline               int32
# Source                int32
# Destination           int32
# Additional_Info       int32
# Price               float64
# Date                  int32
# Month                 int32
# Year                  int32
# Stop                  int32
# Arrival_Hour          int32
# Arrival_Minute        int32
# Departure_Hour        int32
# Departure_Minute      int32
# Route_1               int32
# Route_2               int32
# Route_3               int32
# Route_4               int32
# Route_5               int32
# dtype: object

# %%
big_df.tail()
# Out:
#       Airline  Source  Destination  Additional_Info        Price  Date  Month  \
# 2666        1       3            0                8  9087.064121     6      6
# 2667        3       3            0                8  9087.064121    27      3
# 2668        4       2            1                8  9087.064121     6      3
# 2669        1       2            1                8  9087.064121     6      3
# 2670        6       2            1                8  9087.064121    15      6
#
#       Year  Stop  Arrival_Hour  Arrival_Minute  Departure_Hour  \
# 2666  2019     1            20              25              20
# 2667  2019     0            16              55              14
# 2668  2019     1             4              25              21
# 2669  2019     1            19              15               4
# 2670  2019     1            19              15               4
#
#       Departure_Minute  Route_1  Route_2  Route_3  Route_4  Route_5
# 2666                30        2       14        3       12        4
# 2667                20        2        5       24       12        4
# 2668                50        3        7        6       12        4
# 2669                 0        3        7        6       12        4
# 2670                55        3        7        6       12        4

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
df_train=big_df[0:10683]
df_test=big_df[10683:]

# %%
df_train.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Additional_Info', 'Price', 'Date',
#        'Month', 'Year', 'Stop', 'Arrival_Hour', 'Arrival_Minute',
#        'Departure_Hour', 'Departure_Minute', 'Route_1', 'Route_2', 'Route_3',
#        'Route_4', 'Route_5'],
#       dtype='object')

# %%
X=df_train.drop(['Price'],axis=1)
y=df_train.Price

# %%
X
# Out:
#        Airline  Source  Destination  Additional_Info  Date  Month  Year  Stop  \
# 0            3       0            5                8    24      3  2019     0
# 1            1       3            0                8     1      5  2019     2
# 2            4       2            1                8     9      6  2019     2
# 3            3       3            0                8    12      5  2019     1
# 4            3       0            5                8     1      3  2019     1
# 5            8       3            0                8    24      6  2019     0
# 6            4       0            5                5    12      3  2019     1
# 7            4       0            5                8     1      3  2019     1
# 8            4       0            5                5    12      3  2019     1
# 9            6       2            1                8    27      5  2019     1
# 10           1       2            1                8     1      6  2019     1
# 11           3       3            0                8    18      4  2019     0
# 12           1       1            4                8    24      6  2019     0
# 13           4       3            0                5     9      5  2019     1
# 14           3       3            0                8    24      4  2019     0
# 15           1       2            1                8     3      3  2019     2
# 16           8       2            1                8    15      4  2019     1
# 17           4       2            1                5    12      6  2019     1
# 18           1       2            1                8    12      6  2019     2
# 19           4       2            1                5    27      5  2019     1
# 20           2       2            1                8     6      3  2019     1
# 21           1       0            5                8    21      3  2019     1
# 22           3       0            2                8     3      4  2019     0
# 23           3       0            2                8     1      5  2019     0
# 24           4       3            0                5     6      5  2019     1
# 25           4       2            1                8     9      6  2019     2
# 26           3       2            1                8     1      6  2019     1
# 27           2       2            1                8    15      5  2019     1
# 28          10       0            2                8    18      6  2019     0
# 29          10       1            4                8    15      6  2019     0
# ...        ...     ...          ...              ...   ...    ...   ...   ...
# 10653        4       3            0                8     1      5  2019     1
# 10654        8       0            2                7    12      6  2019     0
# 10655        4       4            3                8     3      5  2019     0
# 10656       10       0            2                8     6      4  2019     0
# 10657        4       3            0                5     6      5  2019     1
# 10658        4       0            2                5    18      6  2019     0
# 10659       10       0            2                8     1      5  2019     0
# 10660       10       0            5                8    21      3  2019     0
# 10661        1       2            1                8     9      5  2019     1
# 10662        1       3            0                8    24      3  2019     2
# 10663        4       2            1                5     6      6  2019     2
# 10664        3       0            2                8     9      4  2019     0
# 10665        3       3            0                8    27      4  2019     0
# 10666        4       2            1                5    12      6  2019     1
# 10667        4       0            5                5    12      3  2019     1
# 10668        4       2            1                8     9      5  2019     2
# 10669        1       2            1                8    15      6  2019     1
# 10670        1       3            0                8    12      5  2019     2
# 10671        1       4            3                8     6      6  2019     0
# 10672        4       2            1                5    27      6  2019     2
# 10673        4       2            1                8    27      5  2019     2
# 10674        4       0            5                5    12      3  2019     1
# 10675        1       4            3                8     9      6  2019     0
# 10676        6       2            1                8     1      5  2019     1
# 10677        8       0            2                7    21      5  2019     0
# 10678        0       3            0                8     9      4  2019     0
# 10679        1       3            0                8    27      4  2019     0
# 10680        4       0            2                8    27      4  2019     0
# 10681       10       0            5                8     1      3  2019     0
# 10682        1       2            1                8     9      5  2019     2
#
#        Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  \
# 0                 1              10              22                20
# 1                13              15               5                50
# 2                 4              25               9                25
# 3                23              30              18                 5
# 4                21              35              16                50
# 5                11              25               9                 0
# 6                10              25              18                55
# 7                 5               5               8                 0
# 8                10              25               8                55
# 9                19              15              11                25
# 10               23               0               9                45
# 11               22              55              20                20
# 12               13              55              11                40
# 13                9              20              21                10
# 14               19              50              17                15
# 15               19              15              16                40
# 16               13              15               8                45
# 17               12              35              14                 0
# 18               19              15              20                15
# 19               12              35              16                 0
# 20               19              20              14                10
# 21               13              20              22                 0
# 22                6              50               4                 0
# 23               21              50              18                55
# 24                8              15              18                55
# 25               12              35              21                25
# 26                3              35              21                50
# 27               12              55               7                 0
# 28               12              35               9                45
# 29                9              20               7                 5
# ...             ...             ...             ...               ...
# 10653            12               0              14                 5
# 10654             8              35               5                55
# 10655             4              20               2                55
# 10656             9              40               7                 0
# 10657             9              20              20                 0
# 10658            14               5              11                10
# 10659            23              50              21                 0
# 10660             0               5              21                10
# 10661            19              15              13                 0
# 10662             5              35               9                25
# 10663            12              35              19                30
# 10664            21              50              18                55
# 10665            17              45              15                15
# 10666            19               0              18                15
# 10667            20              20              22                55
# 10668            19               0              11                40
# 10669            19              15               8                 0
# 10670            23              15               5                50
# 10671            22              25              21                 5
# 10672            19               0              23                 5
# 10673             4              25              13                25
# 10674            21              20              20                35
# 10675             7              40               6                20
# 10676            19               0              10                20
# 10677             8              35               5                55
# 10678            22              25              19                55
# 10679            23              20              20                45
# 10680            11              20               8                20
# 10681            14              10              11                30
# 10682            19              15              10                55
#
#        Route_1  Route_2  Route_3  Route_4  Route_5
# 0            0       13       24       12        4
# 1            2       25        1        3        4
# 2            3       32        4        5        4
# 3            2       34        3       12        4
# 4            0       34        8       12        4
# 5            2        5       24       12        4
# 6            0        7        8       12        4
# 7            0        7        8       12        4
# 8            0        7        8       12        4
# 9            3        7        6       12        4
# 10           3        6        6       12        4
# 11           2        5       24       12        4
# 12           4        8       24       12        4
# 13           2        7        3       12        4
# 14           2        5       24       12        4
# 15           3        0        4        5        4
# 16           3       38        6       12        4
# 17           3        7        6       12        4
# 18           3        9        4        5        4
# 19           3        7        6       12        4
# 20           3        7        6       12        4
# 21           0       11        8       12        4
# 22           0       13       24       12        4
# 23           0       13       24       12        4
# 24           2        7        3       12        4
# 25           3       21        4        5        4
# 26           3       32        6       12        4
# 27           3        7        6       12        4
# 28           0       13       24       12        4
# 29           4        8       24       12        4
# ...        ...      ...      ...      ...      ...
# 10653        2        7        3       12        4
# 10654        0       13       24       12        4
# 10655        1       19       24       12        4
# 10656        0       13       24       12        4
# 10657        2        7        3       12        4
# 10658        0       13       24       12        4
# 10659        0       13       24       12        4
# 10660        0       13       24       12        4
# 10661        3        7        6       12        4
# 10662        2        7       11        3        4
# 10663        3       28        4        5        4
# 10664        0       13       24       12        4
# 10665        2        5       24       12        4
# 10666        3        7        6       12        4
# 10667        0        7        8       12        4
# 10668        3       29        4        5        4
# 10669        3        7        6       12        4
# 10670        2       25        9        3        4
# 10671        1       19       24       12        4
# 10672        3        0        4        5        4
# 10673        3        0        4        5        4
# 10674        0        7        8       12        4
# 10675        1       19       24       12        4
# 10676        3        7        6       12        4
# 10677        0       13       24       12        4
# 10678        2        5       24       12        4
# 10679        2        5       24       12        4
# 10680        0       13       24       12        4
# 10681        0       13       24       12        4
# 10682        3       16        4        5        4
#
# [10683 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=0)

# %%
model=SelectFromModel(Lasso(alpha=0.005,random_state=0))

# %%
model.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
selected_features=X_train.columns[(model.get_support())]

# %%
selected_features
# Out:
# Index(['Airline', 'Source', 'Destination', 'Additional_Info', 'Date', 'Month',
#        'Stop', 'Arrival_Hour', 'Arrival_Minute', 'Departure_Hour',
#        'Departure_Minute', 'Route_1', 'Route_2', 'Route_3', 'Route_4',
#        'Route_5'],
#       dtype='object')

# %%
selected_features
# Out:
# Index(['Airline', 'Source', 'Destination', 'Additional_Info', 'Date', 'Month',
#        'Stop', 'Arrival_Hour', 'Arrival_Minute', 'Departure_Hour',
#        'Departure_Minute', 'Route_1', 'Route_2', 'Route_3', 'Route_4',
#        'Route_5'],
#       dtype='object')

# %%
X_train.head()
# Out:
#       Airline  Source  Destination  Additional_Info  Date  Month  Stop  \
# 7106        8       0            2                8     6      4     0
# 7904        1       2            1                8     1      6     1
# 4861        4       2            1                5    12      6     2
# 9375        3       2            1                8    15      6     1
# 155         1       3            0                8     9      5     2
#
#       Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  Route_1  \
# 7106             8              35               5                55        0
# 7904             6              50               5                15        3
# 4861            12              35              14                35        3
# 9375            21               0               6                40        3
# 155              7              55               8                20        2
#
#       Route_2  Route_3  Route_4  Route_5
# 7106       13       24       12        4
# 7904       41        6       12        4
# 4861       34        4        5        4
# 9375        7        6       12        4
# 155        28        4        3        4

# %%
X_test.drop(['Year'],inplace=True,axis=1)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
X_test.head()
# Out:
#       Airline  Source  Destination  Additional_Info  Date  Month  Stop  \
# 9693        3       2            1                8    27      3     1
# 9825        8       3            0                8    27      5     0
# 7702        1       3            0                8     6      6     2
# 1437        4       0            5                8     6      3     1
# 6828        3       2            1                8    15      6     1
#
#       Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  Route_1  \
# 9693            16              10               4                55        3
# 9825             0              40              22                20        2
# 7702            20              25               5                50        2
# 1437            14              25               9                45        0
# 6828             1              30              16                 0        3
#
#       Route_2  Route_3  Route_4  Route_5
# 9693       20        6       12        4
# 9825        5       24       12        4
# 7702       25        9        3        4
# 1437       33        8       12        4
# 6828        7        6       12        4

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
max_features=['auto','sqrt']
max_depth=[int(x) for x in np.linspace(start=5,stop=30,num=6)]
min_samples_split=[2,5,10,15,100]

# %%
randomgrid={'n_estimators':n_estimators,'max_features':max_features,'max_depth':max_depth,'min_samples_split':min_samples_split}

# %%
randomgrid
# Out:
# {'n_estimators': [100,
#   200,
#   300,
#   400,
#   500,
#   600,
#   700,
#   800,
#   900,
#   1000,
#   1100,
#   1200],
#  'max_features': ['auto', 'sqrt'],
#  'max_depth': [5, 10, 15, 20, 25, 30],
#  'min_samples_split': [2, 5, 10, 15, 100]}

# %%
print(randomgrid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100]}

# %%
regressor_random=RandomizedSearchCV(regressor,param_distributions=randomgrid,scoring='neg_mean_squared_error',n_iter=50,cv=5,verbose=2)

# %%
regressor_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10, total=   1.6s
# [CV] n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV]  n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10, total=   1.3s
# [CV] n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10, total=   1.3s
# [CV] n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10, total=   1.3s
# [CV] n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=200, min_samples_split=100, max_features=sqrt, max_depth=10, total=   1.2s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10, total=   2.0s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10, total=   2.0s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10, total=   2.2s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10, total=   2.0s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=10, total=   1.9s
# [CV] n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15, total=  23.8s
# [CV] n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15, total=  23.2s
# [CV] n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15, total=  23.0s
# [CV] n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15, total=  22.7s
# [CV] n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=900, min_samples_split=5, max_features=auto, max_depth=15, total=  21.7s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20, total=   6.1s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20, total=   6.2s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20, total=   6.4s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20, total=   6.3s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=20, total=   6.5s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25, total=   7.1s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25, total=   6.5s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25, total=   6.0s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25, total=   6.0s
# [CV] n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=800, min_samples_split=10, max_features=sqrt, max_depth=25, total=   6.1s
# [CV] n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25, total=   1.0s
# [CV] n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25, total=   1.0s
# [CV] n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25, total=   0.9s
# [CV] n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25, total=   1.0s
# [CV] n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25
# [CV]  n_estimators=100, min_samples_split=5, max_features=sqrt, max_depth=25, total=   1.0s
# [CV] n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5, total=   0.9s
# [CV] n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5, total=   0.9s
# [CV] n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5, total=   0.9s
# [CV] n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5, total=   0.9s
# [CV] n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=auto, max_depth=5, total=   1.0s
# [CV] n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10, total=   3.5s
# [CV] n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10, total=   3.6s
# [CV] n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10, total=   3.6s
# [CV] n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10, total=   3.4s
# [CV] n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=10, max_features=sqrt, max_depth=10, total=   3.4s
# [CV] n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20, total=  21.6s
# [CV] n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20, total=  23.3s
# [CV] n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20, total=  25.3s
# [CV] n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20, total=  21.0s
# [CV] n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=10, max_features=auto, max_depth=20, total=  21.1s
# [CV] n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15, total=  22.3s
# [CV] n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15, total=  22.2s
# [CV] n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15, total=  23.0s
# [CV] n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15, total=  23.2s
# [CV] n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=5, max_features=auto, max_depth=15, total=  24.6s
# [CV] n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25
# [CV]  n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25, total=  11.0s
# [CV] n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25
# [CV]  n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25, total=  10.8s
# [CV] n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25
# [CV]  n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25, total=  10.9s
# [CV] n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25
# [CV]  n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25, total=  11.0s
# [CV] n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25
# [CV]  n_estimators=600, min_samples_split=15, max_features=auto, max_depth=25, total=  10.5s
# [CV] n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20, total=   2.1s
# [CV] n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20, total=   2.1s
# [CV] n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20, total=   2.2s
# [CV] n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20, total=   2.1s
# [CV] n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=2, max_features=sqrt, max_depth=20, total=   2.2s
# [CV] n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15, total=  14.1s
# [CV] n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15, total=  14.5s
# [CV] n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15, total=  15.0s
# [CV] n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15, total=  14.7s
# [CV] n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=800, min_samples_split=10, max_features=auto, max_depth=15, total=  15.1s
# [CV] n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25, total=   5.6s
# [CV] n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25, total=   5.3s
# [CV] n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25, total=   5.4s
# [CV] n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25, total=   5.4s
# [CV] n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=500, min_samples_split=2, max_features=sqrt, max_depth=25, total=   5.9s
# [CV] n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25, total=  25.6s
# [CV] n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25, total=  24.9s
# [CV] n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25, total=  24.1s
# [CV] n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25, total=  25.5s
# [CV] n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25
# [CV]  n_estimators=900, min_samples_split=2, max_features=auto, max_depth=25, total=  24.3s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25, total=   3.2s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25, total=   3.3s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25, total=   3.5s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25, total=   3.4s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=25, total=   3.3s
# [CV] n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20, total=   7.5s
# [CV] n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20, total=   7.4s
# [CV] n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20, total=   8.3s
# [CV] n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20, total=   8.4s
# [CV] n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=15, max_features=sqrt, max_depth=20, total=   7.4s
# [CV] n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10, total=   4.4s
# [CV] n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10, total=   4.8s
# [CV] n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10, total=   4.5s
# [CV] n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10, total=   4.7s
# [CV] n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=300, min_samples_split=15, max_features=auto, max_depth=10, total=   4.6s
# [CV] n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25, total=   2.1s
# [CV] n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25, total=   2.3s
# [CV] n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25, total=   2.1s
# [CV] n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25, total=   2.5s
# [CV] n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25
# [CV]  n_estimators=300, min_samples_split=15, max_features=sqrt, max_depth=25, total=   2.1s
# [CV] n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15, total=   3.9s
# [CV] n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15, total=   4.3s
# [CV] n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15, total=   5.9s
# [CV] n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15, total=   4.4s
# [CV] n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15
# [CV]  n_estimators=800, min_samples_split=100, max_features=sqrt, max_depth=15, total=   3.8s
# [CV] n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20, total=   9.7s
# [CV] n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20, total=   9.6s
# [CV] n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20, total=   9.3s
# [CV] n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20, total=   9.2s
# [CV] n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1100, min_samples_split=5, max_features=sqrt, max_depth=20, total=   9.5s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20, total=   1.6s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20, total=   1.5s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20, total=   1.6s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20, total=   1.5s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=20, total=   2.0s
# [CV] n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25, total=   6.3s
# [CV] n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25, total=   4.6s
# [CV] n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25, total=   4.5s
# [CV] n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25, total=   4.5s
# [CV] n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=900, min_samples_split=100, max_features=sqrt, max_depth=25, total=   5.1s
# [CV] n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20, total=  12.1s
# [CV] n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20, total=   9.9s
# [CV] n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20, total=  10.9s
# [CV] n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20, total=  14.1s
# [CV] n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=900, min_samples_split=2, max_features=sqrt, max_depth=20, total=  14.1s
# [CV] n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30, total=   2.3s
# [CV] n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30, total=   2.1s
# [CV] n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30, total=   2.7s
# [CV] n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30, total=   2.1s
# [CV] n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=400, min_samples_split=100, max_features=sqrt, max_depth=30, total=   1.9s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30, total=   1.9s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30, total=   1.4s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30, total=   1.5s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30, total=   1.5s
# [CV] n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=100, max_features=sqrt, max_depth=30, total=   1.4s
# [CV] n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10, total=   0.5s
# [CV] n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10, total=   0.5s
# [CV] n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10, total=   0.5s
# [CV] n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10, total=   0.5s
# [CV] n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10
# [CV]  n_estimators=100, min_samples_split=100, max_features=sqrt, max_depth=10, total=   0.5s
# [CV] n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20, total=   6.8s
# [CV] n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20, total=   7.3s
# [CV] n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20, total=   7.0s
# [CV] n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20, total=   7.3s
# [CV] n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20
# [CV]  n_estimators=400, min_samples_split=15, max_features=auto, max_depth=20, total=   7.0s
# [CV] n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25, total=   5.3s
# [CV] n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25, total=   5.3s
# [CV] n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25, total=   5.4s
# [CV] n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25, total=   5.3s
# [CV] n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1200, min_samples_split=100, max_features=sqrt, max_depth=25, total=   5.3s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30, total=   8.4s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30, total=   8.5s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30, total=   8.7s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30, total=   8.7s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=30, total=   9.0s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15, total=  11.7s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15, total=  11.5s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15, total=  11.9s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15, total=  13.7s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=15, total=  11.6s
# [CV] n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20
# [CV]  n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20, total=  24.5s
# [CV] n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20
# [CV]  n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20, total=  20.1s
# [CV] n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20
# [CV]  n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20, total=  20.9s
# [CV] n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20
# [CV]  n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20, total=  18.9s
# [CV] n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20
# [CV]  n_estimators=800, min_samples_split=2, max_features=auto, max_depth=20, total=  19.9s
# [CV] n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15, total=  11.3s
# [CV] n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15, total=  11.8s
# [CV] n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15, total=  11.9s
# [CV] n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15, total=  10.9s
# [CV] n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=600, min_samples_split=10, max_features=auto, max_depth=15, total=  10.9s
# [CV] n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30, total=   2.1s
# [CV] n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30, total=   2.1s
# [CV] n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30, total=   2.2s
# [CV] n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30, total=   2.2s
# [CV] n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30
# [CV]  n_estimators=300, min_samples_split=10, max_features=sqrt, max_depth=30, total=   2.3s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5, total=   4.8s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5, total=   4.5s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5, total=   4.5s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5, total=   4.3s
# [CV] n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1200, min_samples_split=2, max_features=sqrt, max_depth=5, total=   4.7s
# [CV] n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10, total=  14.3s
# [CV] n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10, total=  18.3s
# [CV] n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10, total=  16.8s
# [CV] n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10, total=  16.1s
# [CV] n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10
# [CV]  n_estimators=900, min_samples_split=15, max_features=auto, max_depth=10, total=  15.0s
# [CV] n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20, total=   2.2s
# [CV] n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20, total=   1.9s
# [CV] n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20, total=   1.8s
# [CV] n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20, total=   1.8s
# [CV] n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20
# [CV]  n_estimators=200, min_samples_split=5, max_features=sqrt, max_depth=20, total=   1.8s
# [CV] n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15, total=   7.5s
# [CV] n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15, total=   6.7s
# [CV] n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15, total=   6.7s
# [CV] n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15, total=   6.7s
# [CV] n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=2, max_features=sqrt, max_depth=15, total=   6.8s
# [CV] n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10
# [CV]  n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10, total=  10.2s
# [CV] n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10
# [CV]  n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10, total=   9.6s
# [CV] n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10
# [CV]  n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10, total=  11.7s
# [CV] n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10
# [CV]  n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10, total=  14.3s
# [CV] n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10
# [CV]  n_estimators=800, min_samples_split=100, max_features=auto, max_depth=10, total=  12.8s
# [CV] n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30, total=   3.3s
# [CV] n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30, total=   3.2s
# [CV] n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30, total=   3.6s
# [CV] n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30, total=   3.4s
# [CV] n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30
# [CV]  n_estimators=600, min_samples_split=100, max_features=sqrt, max_depth=30, total=   2.8s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20, total=   3.2s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20, total=   3.1s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20, total=   3.6s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20, total=   3.4s
# [CV] n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=300, min_samples_split=2, max_features=sqrt, max_depth=20, total=   3.4s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5, total=   2.6s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5, total=   3.0s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5, total=   3.0s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5, total=   2.4s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=5, total=   2.6s
# [CV] n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10, total=   3.8s
# [CV] n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10, total=   3.7s
# [CV] n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=600, min_samples_split=2, max_features=sqrt, max_depth=10, total=   4.0s
# [CV] n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15, total=   9.5s
# [CV] n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15, total=   9.5s
# [CV] n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15, total=   9.8s
# [CV] n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15, total=   9.5s
# [CV] n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15
# [CV]  n_estimators=500, min_samples_split=10, max_features=auto, max_depth=15, total=   9.4s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10, total=   5.0s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10, total=   4.9s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10, total=   4.9s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10, total=   4.9s
# [CV] n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10
# [CV]  n_estimators=800, min_samples_split=2, max_features=sqrt, max_depth=10, total=   5.2s
# [CV] n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5, total=   0.5s
# [CV] n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5, total=   0.4s
# [CV] n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5, total=   0.3s
# [CV] n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=10, max_features=sqrt, max_depth=5, total=   0.4s
# [CV] n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15, total=   5.0s
# [CV] n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15, total=   5.1s
# [CV] n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15, total=   5.0s
# [CV] n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15, total=   5.0s
# [CV] n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=700, min_samples_split=10, max_features=sqrt, max_depth=15, total=   5.0s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30, total=   6.3s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30, total=   6.8s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30, total=   6.8s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30, total=   6.0s
# [CV] n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30
# [CV]  n_estimators=700, min_samples_split=5, max_features=sqrt, max_depth=30, total=   6.0s
# [CV] n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30, total=   5.3s
# [CV] n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30, total=   5.2s
# [CV] n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30, total=   5.2s
# [CV] n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30, total=   5.3s
# [CV] n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30
# [CV]  n_estimators=800, min_samples_split=15, max_features=sqrt, max_depth=30, total=   5.3s
# [CV] n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25, total=   7.8s
# [CV] n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25, total=   7.6s
# [CV] n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25, total=   7.5s
# [CV] n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25, total=   7.3s
# [CV] n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25
# [CV]  n_estimators=1000, min_samples_split=10, max_features=sqrt, max_depth=25, total=   6.9s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed: 30.3min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators='warn',
#                                                    n_jobs=None, oob_score=False,
#                                                    random_sta...
#                                                    warm_start=False),
#                    iid='warn', n_iter=50, n_jobs=None,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
regressor_random.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=800,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
ypred=regressor_random.predict(X_test)

# %%
ypred
# Out:
# array([ 6209.4325    ,  3885.09375   , 11821.14029897, ...,
#        11679.83642678, 14257.6183633 ,  7868.445     ])

# %%
from sklearn.metrics import r2_score
score=r2_score(ypred,y_test)

# %%
print(100*score)
# Out:
# 86.31996329530381

# %%
sns.distplot(y_test-ypred)

# %%
plt.scatter(ypred,y_test)
